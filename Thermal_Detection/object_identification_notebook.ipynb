# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    print(dirname)
    # This will print a list of folders. Look for the one ending in 'train/images'
# Out:
# /kaggle/input
# /kaggle/input/datasets
# /kaggle/input/datasets/kausthubkannan
# /kaggle/input/datasets/kausthubkannan/thermal-image-people-detection
# /kaggle/input/datasets/kausthubkannan/thermal-image-people-detection/People Detection - Themal
# /kaggle/input/datasets/kausthubkannan/thermal-image-people-detection/People Detection - Themal/annotations
# /kaggle/input/datasets/kausthubkannan/thermal-image-people-detection/People Detection - Themal/valid
# /kaggle/input/datasets/kausthubkannan/thermal-image-people-detection/People Detection - Themal/valid/labels
# /kaggle/input/datasets/kausthubkannan/thermal-image-people-detection/People Detection - Themal/valid/images
# /kaggle/input/datasets/kausthubkannan/thermal-image-people-detection/People Detection - Themal/test
# /kaggle/input/datasets/kausthubkannan/thermal-image-people-detection/People Detection - Themal/test/labels
# ...

# %%
import yaml

# Replace 'thermal-image-people-detection' if your folder name is different in the output above
data_map = {
    'train': '/kaggle/input/thermal-image-people-detection/train/images',
    'val': '/kaggle/input/thermal-image-people-detection/valid/images',
    'test': '/kaggle/input/thermal-image-people-detection/test/images',
    'nc': 1,
    'names': ['person']
}

with open('/kaggle/working/data.yaml', 'w') as f:
    yaml.dump(data_map, f)

print("✅ data.yaml created in /kaggle/working/")
# Out:
# ✅ data.yaml created in /kaggle/working/

# %%
from ultralytics import YOLO

# 1. Load the model
model = YOLO('yolov8n.pt')

# 2. Train using the GPU
model.train(
    data='/kaggle/working/data.yaml', 
    epochs=25, 
    imgsz=640, 
    batch=32,       # We can use a bigger batch because we have 2 GPUs!
    fraction=0.1,   # Use 10% of data to speed up your first run
    device=[0, 1]   # This tells YOLO to use BOTH of your T4 GPUs
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_55/2538404486.py in <cell line: 0>()
# ----> 1 from ultralytics import YOLO
#       2
#       3 # 1. Load the model
#       4 model = YOLO('yolov8n.pt')
#       5
#
# ModuleNotFoundError: No module named 'ultralytics'

# %%
# !pip install ultralytics
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7d0ef7b080b0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/ultralytics/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7d0ef7b58320>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/ultralytics/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7d0ef7b537a0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/ultralytics/
# ...

# %%
import os
# Notice the 'Themal' spelling below to match your sidebar
print(os.listdir('/kaggle/input/datasets/kausthubkannan/thermal-image-people-detection'))
# Out:
# ['People Detection - Themal']

# %%
import yaml

# Updated with 'val' instead of 'valid'
data_map = {
    'train': '/kaggle/input/thermal-image-people-detection/People Detection - Themal/train/images',
    'val': '/kaggle/input/thermal-image-people-detection/People Detection - Themal/val/images', 
    'nc': 1,
    'names': ['person']
}

with open('/kaggle/working/data.yaml', 'w') as f:
    yaml.dump(data_map, f)

print("✅ data.yaml updated! 'valid' changed to 'val'.")
# Out:
# ✅ data.yaml updated! 'valid' changed to 'val'.

# %%
from ultralytics import YOLO

# 1. Load the pre-trained YOLOv8 Nano model
# This is the 'base' the AI will start learning from
model = YOLO('yolov8n.pt')

# 2. Start the training process
results = model.train(
    data='/kaggle/working/data.yaml',
    epochs=25,          # 25 full cycles through the data
    imgsz=640,          # Standard image resolution for YOLO
    batch=64,           # Look at 64 images at once (uses your big VRAM)
    device=[0, 1],      # <--- IMPORTANT: This tells it to use both GPUs
    workers=4,          # Helps load images faster
    fraction=0.1,       # START WITH THIS: Only uses 10% of data for a quick test
    name='FYP_Thermal_People'
)
# Out:
# Ultralytics 8.4.34 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                        CUDA:1 (Tesla T4, 14913MiB)
# ...

# %%
import os

# This search will find where the 'images' folder actually lives
for root, dirs, files in os.walk('/kaggle/input'):
    if 'train/images' in root:
        print(f"COPY THIS FOR TRAIN: {root}")
    if 'val/images' in root or 'valid/images' in root:
        print(f"COPY THIS FOR VAL: {root}")
# Out:
# COPY THIS FOR VAL: /kaggle/input/datasets/kausthubkannan/thermal-image-people-detection/People Detection - Themal/valid/images
# COPY THIS FOR TRAIN: /kaggle/input/datasets/kausthubkannan/thermal-image-people-detection/People Detection - Themal/train/images

# %%
import yaml

# Paste the results from Step 1 into these variables
train_path = '/kaggle/input/datasets/kausthubkannan/thermal-image-people-detection/People Detection - Themal/train/images'
val_path = '/kaggle/input/datasets/kausthubkannan/thermal-image-people-detection/People Detection - Themal/valid/images'

data_map = {
    'train': train_path,
    'val': val_path, 
    'nc': 1,
    'names': ['person']
}

with open('/kaggle/working/data.yaml', 'w') as f:
    yaml.dump(data_map, f)

print("✅ data.yaml re-written with deep paths!")
# Out:
# ✅ data.yaml re-written with deep paths!

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

model.train(
    data='/kaggle/working/data.yaml', 
    epochs=25, 
    imgsz=640, 
    batch=32, 
    fraction=0.1, # Keep this at 0.1 for the first test!
    device=[0, 1] 
)
# Out:
# Ultralytics 8.4.34 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                        CUDA:1 (Tesla T4, 14913MiB)
# ...

# %%
# 1. Install YOLO
import os
import subprocess
import sys

def install(package):
    subprocess.check_call([sys.executable, "-m", "pip", "install", package])

install('ultralytics')

from ultralytics import YOLO
import yaml
import os

# The exact path based on your logs
base_path = '/kaggle/input/thermal-image-people-detection/People Detection - Themal/People Detection - Themal'

data_map = {
    'train': f'{base_path}/train/images',
    'val': f'{base_path}/val/images',   # <--- CHANGED FROM 'valid' TO 'val'
    'nc': 1,
    'names': ['person']
}

with open('/kaggle/working/data.yaml', 'w') as f:
    yaml.dump(data_map, f)

print("✅ data.yaml updated with the correct 'val' path!")

# 3. TRAINING
model = YOLO('yolov8n.pt')
model.train(
    data='/kaggle/working/data.yaml',
    epochs=25,
    imgsz=640,
    batch=32,
    device=[0, 1],
    fraction=0.1
)
# Out:
# ...
# ✅ data.yaml updated with the correct 'val' path!
# Ultralytics 8.4.34 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                        CUDA:1 (Tesla T4, 14913MiB)
# ...

# %%
import os
import yaml

# The base path we know is correct
base = '/kaggle/input/thermal-image-people-detection/People Detection - Themal/People Detection - Themal'

# Auto-detect if it is 'val' or 'valid'
val_folder = 'val' if os.path.exists(f'{base}/val') else 'valid'

data_map = {
    'train': f'{base}/train/images',
    'val': f'{base}/{val_folder}/images', 
    'nc': 1,
    'names': ['person']
}

with open('/kaggle/working/data.yaml', 'w') as f:
    yaml.dump(data_map, f)

print(f"✅ data.yaml created! Using '{val_folder}' for validation.")
# Out:
# ✅ data.yaml created! Using 'valid' for validation.

# %%
from ultralytics import YOLO

# 1. Load model
model = YOLO('yolov8n.pt')

# 2. Train
model.train(
    data='/kaggle/working/data.yaml',
    epochs=25,
    imgsz=640,
    batch=32,
    device=[0, 1],
    fraction=0.1,
    exist_ok=True  # Overwrites existing folders to avoid errors
)
# Out:
# Ultralytics 8.4.34 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                        CUDA:1 (Tesla T4, 14913MiB)
# ...

# %%
import os
import yaml

# Search for the actual image folders
train_path = ""
val_path = ""

for root, dirs, files in os.walk('/kaggle/input'):
    if 'train/images' in root:
        train_path = root
    if ('val/images' in root) or ('valid/images' in root):
        val_path = root

if train_path and val_path:
    print(f"✅ Found Train: {train_path}")
    print(f"✅ Found Val: {val_path}")
    
    # Create the data.yaml using the FOUND paths
    data_map = {
        'train': train_path,
        'val': val_path,
        'nc': 1,
        'names': ['person']
    }

    with open('/kaggle/working/data.yaml', 'w') as f:
        yaml.dump(data_map, f)
    print("🚀 data.yaml is now PERFECTly mapped!")
else:
    print("❌ Error: Could not find images. Please check if the dataset is attached correctly.")
# Out:
# ✅ Found Train: /kaggle/input/datasets/kausthubkannan/thermal-image-people-detection/People Detection - Themal/train/images
# ✅ Found Val: /kaggle/input/datasets/kausthubkannan/thermal-image-people-detection/People Detection - Themal/valid/images
# 🚀 data.yaml is now PERFECTly mapped!

# %%
from ultralytics import YOLO

# 1. Load the model
model = YOLO('yolov8n.pt')

# 2. Train using both T4 GPUs
model.train(
    data='/kaggle/working/data.yaml',
    epochs=25,
    imgsz=640,
    batch=32,
    device=[0, 1],
    fraction=0.1,    # Stick to 10% for this quick test
    exist_ok=True    # Overwrites existing run folders
)
# Out:
# Ultralytics 8.4.35 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
#                                                        CUDA:1 (Tesla T4, 14913MiB)
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.9 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import shutil
import os
from IPython.display import FileLink

# 1. Create a zip file of the entire 'train' folder
# This packs all graphs, samples, and weights into one file
shutil.make_archive('FYP_Final_Results', 'zip', '/kaggle/working/runs/detect/train')

# 2. Create a download link
print("✅ All files zipped! Click the link below to download everything for your advisor:")
FileLink('FYP_Final_Results.zip')
# Out:
# ✅ All files zipped! Click the link below to download everything for your advisor:
# /kaggle/working/FYP_Final_Results.zip
